# %%
# --- en la primera celda del notebook
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

# añade la carpeta raíz del proyecto al sys.path
PROJECT_ROOT = Path.cwd()   # si la nb está junto a "portafolios/"

# %%
from portafolios.core.portafolio import Portfolio
from portafolios.data.local_loader import local_loader
from portafolios.constructores.naive import Naive

# %%
csv_path = "data_clean_stock_data.csv"

# loader que ignora tickers/start/end y lee TU csv
loader_from_csv = lambda *args, **kwargs: local_loader(*args, **kwargs, path=csv_path)

p = (Portfolio(
        tickers=None,
        start="2019-01-01",
        end="2019-12-31",
        loader=local_loader,
        loader_kwargs={"path": csv_path, "prefer_adj_close": True},
        freq="B",
     )
     .preparar_datos()
                  # ← capa de métricas por activo
)

# %%
print("Tickers:", p.tickers[:10])   # muestra algunos
p.prices.head()
# Out:
# Tickers: ['AAPL', 'ABBV', '0ABT', '0ACN', 'ADBE', '0AMD', 'AMGN', 'AMZN', 'AVGO', '0BAC']
#                  AAPL       ABBV       0ABT        0ACN        ADBE  \
# Date
# 2019-01-02  37.889009  69.054458  63.640057  129.554251  226.169998
# 2019-01-03  34.757238  67.193050  61.774625  128.067714  223.630005
# 2019-01-04  35.432248  67.450306  61.505575  129.691815  227.649994
# 2019-01-07  35.499034  68.676139  62.653528  130.636997  232.600006
# 2019-01-08  36.212212  69.841416  62.456216  134.711035  233.770004
#
#                  0AMD        AMGN       AMZN       AVGO       0BAC  ...  \
# Date                                                                ...
# 2019-01-02  19.000000  159.660719  77.667999  21.292662  21.706751  ...
# 2019-01-03  18.680000  160.470578  76.900002  20.610491  21.620407  ...
# 2019-01-04  19.070000  162.404371  79.699997  19.766979  22.147104  ...
# 2019-01-07  20.680000  164.751309  81.727997  20.083820  22.259350  ...
# ...

# %%
p.asset_log_returns
# Out:
#                 AAPL      ABBV      0ABT      0ACN      ADBE      0AMD  \
# Date
# 2019-01-03 -0.086273 -0.027326 -0.029750 -0.011541 -0.011294 -0.016986
# 2019-01-04  0.019235  0.003821 -0.004365  0.012602  0.017816  0.020663
# 2019-01-07  0.001883  0.018011  0.018492  0.007261  0.021511  0.081051
# 2019-01-08  0.019891  0.016825 -0.003154  0.030710  0.005017  0.024834
# 2019-01-09  0.017693 -0.009908  0.003011  0.002653  0.020409  0.011257
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-12-26  0.017709  0.003534  0.000457  0.002124 -0.000785  0.014907
# 2019-12-27  0.013665 -0.004862  0.002625  0.002401  0.004818 -0.009131
# 2019-12-30 -0.004364 -0.006111  0.000456 -0.001836 -0.007266 -0.015261
# 2019-12-31  0.003377 -0.012673 -0.009154 -0.005575 -0.001605 -0.001734
#
#                 AMGN      AMZN      AVGO      0BAC  ...      0TMO      TSLA  \
# ...

# %%
p.construir(Naive())  
p.weights
# Out:
# 000V    0.020408
# 00HD    0.020408
# 00KO    0.020408
# 00MA    0.020408
# 00PG    0.020408
# 00PM    0.020408
# 00VZ    0.020408
# 0ABT    0.020408
# 0ACN    0.020408
# 0AMD    0.020408
# 0BAC    0.020408
# 0BMY    0.020408
# 0CRM    0.020408
# 0CVX    0.020408
# 0DHR    0.020408
# 0DIS    0.020408
# 0HON    0.020408
# 0JPM    0.020408
# 0LIN    0.020408
# 0LLY    0.020408
# 0MCD    0.020408
# 0MRK    0.020408
# 0NEE    0.020408
# 0NKE    0.020408
# 0PEP    0.020408
# 0PFE    0.020408
# 0TMO    0.020408
# 0TXN    0.020408
# 0UNH    0.020408
# 0UPS    0.020408
# 0WFC    0.020408
# 0WMT    0.020408
# 0XOM    0.020408
# AAPL    0.020408
# ABBV    0.020408
# ADBE    0.020408
# AMGN    0.020408
# AMZN    0.020408
# AVGO    0.020408
# COST    0.020408
# CSCO    0.020408
# GOOG    0.020408
# INTC    0.020408
# META    0.020408
# MSFT    0.020408
# NFLX    0.020408
# NVDA    0.020408
# ORCL    0.020408
# TSLA    0.020408
# dtype: float64

# %%
# KPIs por momentos (per-period por defecto)
p.kpi("exp_return")
# Out:
# 0.001183347468500027

# %%
p.kpi("vol")
# Out:
# np.float64(0.006895915240408382)

# %%
p.kpi("sharpe_m", rf_per_period=0.0, ann_factor=252)
# Out:
# np.float64(2.7240849172996793)

# %%
# Resumen básico
p.kpis_basicos(ann_factor=252, rf_per_period=0.0)
# Out:
# {'expected_return': 0.29820356206200677,
#  'volatility': np.float64(0.10946926072980462),
#  'sharpe_m': np.float64(2.7240849172996793)}

# %%
p.kpis_basicos(rf_per_period=0.0)
# Out:
# {'expected_return': 0.001183347468500027,
#  'volatility': np.float64(0.006895915240408382),
#  'sharpe_m': np.float64(0.1716012200332596)}
